# %% [markdown]
# # Python 下載XML檔案與解析
#
#
# * 了解 xml 檔案格式與內容
# * 能夠利用套件存取 xml 格式的檔案

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「File I/O」與「xmltodict」讀出來的內容有什麼差異
#
# * 根據範例檔案的結果：
#     1. 請問高雄市有多少地區有溫度資料？
#     2. 請取出每一個地區所記錄的第一個時間點跟溫度
#     3. 請取出第一個地區所記錄的每一個時間點跟溫度

# %% [markdown]
# ### 比較一下範例檔案中的「File I/O」與「xmltodict」讀出來的內容有什麼差異

# %%
import xmltodict

# 存取檔案

with open('./64_72hr_CH.xml', encoding='utf8') as fd:
    doc = dict(xmltodict.parse(fd.read()))

doc['cwbopendata']['dataset']['locations']['location']
# 存取我們的資訊
#print(doc['cwbopendata']['dataset']['locations'])
#print(doc['CUPOY']['Author'])

# 用迴圈存取我們的資訊
#locs = doc['cwbopendata']['dataset']['locations']
#for loc in locs:
#    print (loc['locationName'], loc['weatherElement'])

# %% [markdown]
# ### 根據範例檔案的結果：
#
# 1. 請問高雄市有多少地區有溫度資料？
# 2. 請取出每一個地區所記錄的第一個時間點跟溫度
# 3. 請取出第一個地區所記錄的每一個時間點跟溫度

# %%
# 1. 請問高雄市有多少地區有溫度資料？

import xmltodict

# 存取檔案

with open('./64_72hr_CH.xml', encoding='utf8') as fd:
    doc = dict(xmltodict.parse(fd.read()))

doc['cwbopendata']['dataset']['locations']['location']['locationName' == '鹽埕區']
# Out:
# OrderedDict([('locationName', '鹽埕區'),
#              ('geocode', '6400100'),
#              ('lat', '22.626497'),
#              ('lon', '120.278707'),
#              ('weatherElement',
#               [OrderedDict([('elementName', 'T'),
#                             ('description', '溫度'),
#                             ('time',
#                              [OrderedDict([('dataTime',
#                                             '2019-06-28T12:00:00+08:00'),
#                                            ('elementValue',
#                                             OrderedDict([('value', '33'),
#                                                          ('measures',
#                                                           '攝氏度')]))]),
#                               OrderedDict([('dataTime',
#                                             '2019-06-28T15:00:00+08:00'),
#                                            ('elementValue',
# ...

# %%
# 2. 請取出每一個地區所記錄的第一個時間點跟溫度

import xmltodict

# 存取檔案

with open('./64_72hr_CH.xml', encoding='utf8') as fd:
    doc = dict(xmltodict.parse(fd.read()))
    
locs = doc['cwbopendata']['dataset']['locations']['location']
for loc in locs:
    area = loc['locationName']
    print(loc['locationName']['weatherElement'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-91c8d2cad768> in <module>
#      11 for loc in locs:
#      12     area = loc['locationName']
# ---> 13     print(loc['locationName']['weatherElement'])
#
# TypeError: string indices must be integers

# %%
# 3. 請取出第一個地區所記錄的每一個時間點跟溫度

'''
Your Code
'''
