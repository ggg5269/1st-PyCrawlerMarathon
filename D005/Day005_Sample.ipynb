.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2019-11-29T00:25:38.826Z","updatedAt":"2019-11-29T00:25:38.826Z"},{"id":"b930dc1f-af47-4416-a90a-cd5570744fcf","url":"https://i.imgur.com/5O5r7kK.jpg","normalizedUrl":"https://imgur.com/5O5r7kK","thumbnail":"https://i.imgur.com/5O5r7kKl.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2019-11-29T00:25:38.826Z","updatedAt":"2019-11-29T00:25:38.826Z"},{"id":"2ac981c6-6701-44e9-adde-f12252e3426f","url":"https://i.imgur.com/bVTtKsJ.jpg","normalizedUrl":"https://imgur.com/bVTtKsJ","thumbnail":"https://i.imgur.com/bVTtKsJl.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2019-11-29T00:25:38.826Z","updatedAt":"2019-11-29T00:25:38.826Z"}],"reactions":[{"id":"286f599c-f86a-4932-82f0-f5a06f1eca03","count":2554},{"id":"e8e6bc5d-41b0-4129-b134-97507523d7ff","count":56}],"hidden":false,"customStyle":null,"isSuspiciousAccount":false,"layout":"classic","withImages":true,"withVideos":false,"media":[{"url":"https://i.imgur.com/MJKqP3i.jpg"},{"url":"https://i.imgur.com/IN7zt7r.jpg"},{"url":"https://i.imgur.com/wa1l0lB.jpg"},{"url":"https://i.imgur.com/bp02xDm.jpg"},{"url":"https://i.imgur.com/LTuZyIi.jpg"},{"url":"https://i.imgur.com/eN2qDDZ.jpg"},{"url":"https://i.imgur.com/5O5r7kK.jpg"},{"url":"https://i.imgur.com/bVTtKsJ.jpg"}],"reportReasonText":"","postAvatar":""},{"id":232586555,"title":"這些狗你認識嗎😍","excerpt":"1. Pinky，Pinky是Selina養的紅貴賓，知道Pi ...

# %%
import json
data = json.loads(response)

for d in data:
    print(d['title'])
# Out:
# 不要被薩摩耶給騙了！
# 這些狗你認識嗎😍
# 充滿柴柴的人生❤️
# #圖多 偷看🐹上廁所......
# 請問這樣算不算虐貓
# 兄弟貓🧐
# #圖 柴柴 你能懂我的明白嗎？
# 沒有責任感根本沒資格養寵物
# 紙袋破壞王🏆
# 高科大校板的遺失倉鼠
# 我竟然被我家ㄉ狗鄙視！
# 天冷怎麼辦ಥ_ಥ #柯基#圖多
# 貓咪教妳皮笑肉不笑🙂
# 🐰誰說兔子不能碰水！兔子❤️海灘
# #募款 #貓 愛在街角，守護浪貓
# 你也知道要坐那
# 求吸鴨地點
# 請問有人的柴犬走失嗎？(已找到失主，謝謝大家的幫忙🙏）
# 我養了一隻樹懶🦥
# 吸貓治百病
# 就是你！！！我的菜！！！
# 有愛的假兄弟
# 當我的貓和海豹都是一個囧臉
# 我家柴犬一系列照片
# 協尋幼犬
# 限動裡的小三線們
# 囤貓囤起來😻/圖多文長
# 👻我的隱形貓貓
# 走失狗狗
# 問貓貓的帳號

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
#     1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
#     2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
#     3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」
