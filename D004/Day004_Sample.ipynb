# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 下載檔案

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"10975218458","type":"PushEvent","actor":{"id":37587639,"login":"CRGGithub","display_login":"CRGGithub","gravatar_id":"","url":"https://api.github.com/users/CRGGithub","avatar_url":"https://avatars.githubusercontent.com/u/37587639?"},"repo":{"id":126046415,"name":"CRGGithub/crggithub.github.io","url":"https://api.github.com/repos/CRGGithub/crggithub.github.io"},"payload":{"push_id":4335435127,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"d9a792f7def2397e6a2d588a7dd3c9634c3e07bf","before":"cb107448725425f3891503db7ae146ace11fa7d3","commits":[{"sha":"d9a792f7def2397e6a2d588a7dd3c9634c3e07bf","author":{"email":"henno@ggf-bongani.puk.ac.za","name":"henno"},"message":"20191129","distinct":true,"url":"https://api.github.com/repos/CRGGithub/crggithub.github.io/commits/d9a792f7def2397e6a2d588a7dd3c9634c3e07bf"}]},"public":true,"created_at":"2019-11-29T10:55:11Z"},{"id":"10975218448","type":"PushEvent","actor":{"id":4945153,"login":"apan1121","display_login":"apan1121","gravatar_id":"","url":"https://api.github.com/users/apan1121","avatar_url":"https://avatars.githubusercontent.com/u/4945153?"},"repo":{"id":98047378,"name":"apan1121/powerInfo","url":"https://api.github.com/repos/apan1121/powerInfo"},"payload":{"push_id":4335435125,"size":1,"distinct_size":1,"ref":"refs/heads/gh-pages","head":"cbba61bf76354392b8c8b62361dc17325029c2b6","before":"718073cc68ef33c3a5989851045ad2be565e0aaf","commits":[{"sha":"cbba61bf76354392b8c8b62361dc17325029c2b6","author":{"email":"apan1121@gmail.com","name":"byron-linode"},"message":"[auto] add new log","distinct":true,"url":"https://api.github.com/repos/apan1121/powerInfo/commits/cbba61bf76354392b8c8b62361dc17325029c2b6"}]},"public":true,"created_at":"2019-11-29T10:55:11Z"},{"id":"10975218441","type":"PushEvent","actor":{"id":45519553,"login":"rapaMatiase","display_login":"rapaMatiase","gravatar_id":"","url":"https://api.github.com/users/rapaMatiase","avatar_url":"https://avatars.githubusercontent.com/u/45519553?"},"repo":{"id":224832625,"name":"rapaMatiase/RepoParaBysect","url":"https://api.github.com/repos/rapaMatiase/RepoParaBysect"},"payload":{"push_id":4335435115,"size":2,"distinct_size":2,"ref":"refs/heads/master","head":"6a4a76be18ebef0ba373770d26cffdf5f0d7d53e","before":"fe6c288e9a8dc307a28c5de498c65b300df4f8ab","commits":[{"sha":"1fcea9fd0636afaad5bb89153a347468137e3dd4","author":{"email":"rapa.matias.e@gmail.com","name":"rapamatiase"},"message":"Otro archivo","distinct":true,"url":"https://api.github.com/repos/rapaMatiase/RepoParaBysect/commits/1fcea9fd0636afaad5bb89153a347468137e3dd4"},{"sha":"6a4a76be18ebef0ba373770d26cffdf5f0d7d53e","author":{"email":"rapa.matias.e@gmail.com","name":"rapamatiase"},"message":"Funcionalidades sin terminarr","distinct":true,"url":"https://api.github.com/repos/rapaMatiase/RepoParaBysect/commits/6a4a76be18ebef0ba373770d26cffdf5f0d7d53e"}]},"public":true,"created_at":"2019-11-29T10:55:11Z"},{"id":"10975218444","type":"PushEvent","actor":{"id":30635657,"login":"maptupocob","display_login":"maptupocob","gravatar_id":"","url":"https://api.github.com/users/maptupocob","avatar_url":"https://avatars.githubusercontent.com/u/30635657?"},"repo":{"id":220034158,"name":"maptupocob/Java3","url":"https://api.github.com/repos/maptupocob/Java3"},"payload":{"push_id":4335435116,"size":5,"distinct_size":5,"ref":"refs/heads/HW7","head":"5037a9c3554f2c8e699a36b11e3e97be8d4e40de","before":"2d9eebf7d1fbe2289d8e278505796daae17798bb","commits":[{"sha":"4720f542d969da6fb4059c0733af1d3ba911e04a","author":{"email":"30635657+maptupocob@users.noreply.github.com","name":"maptupocob"},"message":"HW7 files replaced","distinct":true,"url":"https://api.github.com/repos/maptupocob/Java3/commits/4720f542d969da6fb4059c0733af1d3ba911e04a"},{"sha":"7c139767b2124eb5fedaf8f5f8fbba9a24e042ae","author":{"email":"30635657+maptupocob@users.noreply.github.com","name":"maptupocob"},"message":"HW7 files replaced","distinct":true,"url":"https://api.github.com/repos/maptupocob/Java3/comm ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '10975218458',
#   'type': 'PushEvent',
#   'actor': {'id': 37587639,
#    'login': 'CRGGithub',
#    'display_login': 'CRGGithub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CRGGithub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37587639?'},
#   'repo': {'id': 126046415,
#    'name': 'CRGGithub/crggithub.github.io',
#    'url': 'https://api.github.com/repos/CRGGithub/crggithub.github.io'},
#   'payload': {'push_id': 4335435127,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd9a792f7def2397e6a2d588a7dd3c9634c3e07bf',
#    'before': 'cb107448725425f3891503db7ae146ace11fa7d3',
#    'commits': [{'sha': 'd9a792f7def2397e6a2d588a7dd3c9634c3e07bf',
#      'author': {'email': 'henno@ggf-bongani.puk.ac.za', 'name': 'henno'},
#      'message': '20191129',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/CRGGithub/crggithub.github.io/commits/d9a792f7def2397e6a2d588a7dd3c9634c3e07bf'}]},
#   'public': True,
#   'created_at': '2019-11-29T10:55:11Z'},
#  {'id': '10975218448',
#   'type': 'PushEvent',
#   'actor': {'id': 4945153,
#    'login': 'apan1121',
#    'display_login': 'apan1121',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/apan1121',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4945153?'},
#   'repo': {'id': 98047378,
#    'name': 'apan1121/powerInfo',
#    'url': 'https://api.github.com/repos/apan1121/powerInfo'},
#   'payload': {'push_id': 4335435125,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': 'cbba61bf76354392b8c8b62361dc17325029c2b6',
#    'before': '718073cc68ef33c3a5989851045ad2be565e0aaf',
#    'commits': [{'sha': 'cbba61bf76354392b8c8b62361dc17325029c2b6',
#      'author': {'email': 'apan1121@gmail.com', 'name': 'byron-linode'},
#      'message': '[auto] add new log',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/apan1121/powerInfo/commits/cbba61bf76354392b8c8b62361dc17325029c2b6'}]},
#   'public': True,
#   'created_at': '2019-11-29T10:55:11Z'},
#  {'id': '10975218441',
#   'type': 'PushEvent',
#   'actor': {'id': 45519553,
#    'login': 'rapaMatiase',
#    'display_login': 'rapaMatiase',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rapaMatiase',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45519553?'},
#   'repo': {'id': 224832625,
#    'name': 'rapaMatiase/RepoParaBysect',
#    'url': 'https://api.github.com/repos/rapaMatiase/RepoParaBysect'},
#   'payload': {'push_id': 4335435115,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': '6a4a76be18ebef0ba373770d26cffdf5f0d7d53e',
#    'before': 'fe6c288e9a8dc307a28c5de498c65b300df4f8ab',
#    'commits': [{'sha': '1fcea9fd0636afaad5bb89153a347468137e3dd4',
#      'author': {'email': 'rapa.matias.e@gmail.com', 'name': 'rapamatiase'},
#      'message': 'Otro archivo',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/rapaMatiase/RepoParaBysect/commits/1fcea9fd0636afaad5bb89153a347468137e3dd4'},
#     {'sha': '6a4a76be18ebef0ba373770d26cffdf5f0d7d53e',
#      'author': {'email': 'rapa.matias.e@gmail.com', 'name': 'rapamatiase'},
#      'message': 'Funcionalidades sin terminarr',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/rapaMatiase/RepoParaBysect/commits/6a4a76be18ebef0ba373770d26cffdf5f0d7d53e'}]},
#   'public': True,
#   'created_at': '2019-11-29T10:55:11Z'},
#  {'id': '10975218444',
#   'type': 'PushEvent',
#   'actor': {'id': 30635657,
#    'login': 'maptupocob',
#    'display_login': 'maptupocob',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/maptupocob',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30635657?'},
#   'repo': {'id': 220034158,
#    'name': 'maptupocob/Java3',
#    'url': 'https://api.github.com/repos/maptupocob/Java3'},
#   'payload': {'push_id': 4335435116,
#    'size': 5,
#    'distinct_size': 5,
#    'ref': 'refs/heads/HW7',
#    'head': '5037a9c3554f2c8e699a36b11e3e97be8d4e40de',
#    'before': '2d9eebf7d1fbe2289d8e278505796daae17798bb',
#    'commits': [{'sha': '4720f542d969da6fb4059c0733af1d3ba911e04a',
#      'author': {'email': '30635657+maptupocob@users.noreply.github.com',
#       'name': 'maptupocob'},
#      'message': 'HW7 files replaced',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/maptupocob/Java3/commits/4720f542d969da6fb4059c0733af1d3ba911e04a'},
#     {'sha': '7c139767b2124eb5fedaf8f5f8fbba9a24e042ae',
#      'author': {'email': '30635657+maptupocob@users.noreply.github.com',
#       'name': 'maptupocob'},
#      'message': 'HW7 files replaced',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/maptupocob/Java3/commits/7c139767b2124eb5fedaf8f5f8fbba9a24e042ae'},
#     {'sha': '9f6a89c2e865e1937734ec391e384f26255cb24f',
#      'author': {'email': '30635657+maptupocob@users.noreply.github.com',
#       'name': 'maptupocob'},
#      'message': 'refactor. Add test for single Before and After.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/maptupocob/Java3/commits/9f6a89c2e865e1937734ec391e384f26255cb24f'},
#     {'sha': '1397cead0355fec33599fc4d390a4f459b0cd913',
#      'author': {'email': '30635657+maptupocob@users.noreply.github.com',
#       'name': 'maptupocob'},
#      'message': 'change local variable to method argument',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/maptupocob/Java3/commits/1397cead0355fec33599fc4d390a4f459b0cd913'},
#     {'sha': '5037a9c3554f2c8e699a36b11e3e97be8d4e40de',
#      'author': {'email': '30635657+maptupocob@users.noreply.github.com',
#       'name': 'maptupocob'},
#      'message': 'fixed some warnings',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/maptupocob/Java3/commits/5037a9c3554f2c8e699a36b11e3e97be8d4e40de'}]},
#   'public': True,
#   'created_at': '2019-11-29T10:55:11Z'},
#  {'id': '10975218430',
#   'type': 'ForkEvent',
#   'actor': {'id': 14169258,
#    'login': 'kauppfbi',
#    'display_login': 'kauppfbi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kauppfbi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/14169258?'},
#   'repo': {'id': 203580945,
#    'name': 'angular-schule/ngx-deploy-starter',
#    'url': 'https://api.github.com/repos/angular-schule/ngx-deploy-starter'},
#   'payload': {'forkee': {'id': 224836131,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyMjQ4MzYxMzE=',
#     'name': 'ngx-deploy-starter',
#     'full_name': 'kauppfbi/ngx-deploy-starter',
#     'private': False,
#     'owner': {'login': 'kauppfbi',
#      'id': 14169258,
#      'node_id': 'MDQ6VXNlcjE0MTY5MjU4',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/14169258?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/kauppfbi',
#      'html_url': 'https://github.com/kauppfbi',
#      'followers_url': 'https://api.github.com/users/kauppfbi/followers',
#      'following_url': 'https://api.github.com/users/kauppfbi/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/kauppfbi/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/kauppfbi/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/kauppfbi/subscriptions',
#      'organizations_url': 'https://api.github.com/users/kauppfbi/orgs',
#      'repos_url': 'https://api.github.com/users/kauppfbi/repos',
#      'events_url': 'https://api.github.com/users/kauppfbi/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/kauppfbi/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/kauppfbi/ngx-deploy-starter',
#     'description': 'Starter repository to create a new builder to utilize the `ng deploy` command 🚀',
#     'fork': True,
#     'url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter',
#     'forks_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/forks',
#     'keys_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/teams',
#     'hooks_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/hooks',
#     'issue_events_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/events',
#     'assignees_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/tags',
#     'blobs_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/languages',
#     'stargazers_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/stargazers',
#     'contributors_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/contributors',
#     'subscribers_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/subscribers',
#     'subscription_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/subscription',
#     'commits_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/merges',
#     'archive_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/downloads',
#     'issues_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/kauppfbi/ngx-deploy-starter/deployments',
#     'created_at': '2019-11-29T10:55:10Z',
#     'updated_at': '2019-11-06T18:31:33Z',
#     'pushed_at': '2019-11-06T18:31:31Z',
#     'git_url': 'git://github.com/kauppfbi/ngx-deploy-starter.git',
#     'ssh_url': 'git@github.com:kauppfbi/ngx-deploy-starter.git',
#     'clone_url': 'https://github.com/kauppfbi/ngx-deploy-starter.git',
#     'svn_url': 'https://github.com/kauppfbi/ngx-deploy-starter',
#     'homepage': 'https://www.npmjs.com/package/@angular-schule/ngx-deploy-starter',
#     'size': 2747,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2019-11-29T10:55:11Z',
#   'org': {'id': 26645266,
#    'login': 'angular-schule',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/angular-schule',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26645266?'}},
#  {'id': '10975218432',
#   'type': 'WatchEvent',
#   'actor': {'id': 22131067,
#    'login': 'stephanieangelabrauer',
#    'display_login': 'stephanieangelabrauer',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/stephanieangelabrauer',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22131067?'},
#   'repo': {'id': 2493904,
#    'name': 'apache/tomcat',
#    'url': 'https://api.github.com/repos/apache/tomcat'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-11-29T10:55:11Z',
#   'org': {'id': 47359,
#    'login': 'apache',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/apache',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47359?'}},
#  {'id': '10975218418',
#   'type': 'PushEvent',
#   'actor': {'id': 17919858,
#    'login': 'MlgmXyysd',
#    'display_login': 'MlgmXyysd',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MlgmXyysd',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17919858?'},
#   'repo': {'id': 168368507,
#    'name': 'ElderDrivers/Repository-Website',
#    'url': 'https://api.github.com/repos/ElderDrivers/Repository-Website'},
#   'payload': {'push_id': 4335435105,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': '481f60f8cf87116c290409d2deb3490487bb4d8e',
#    'before': 'e47ce2546fc091fdb24b5bbc8aad246d57a76584',
#    'commits': [{'sha': '481f60f8cf87116c290409d2deb3490487bb4d8e',
#      'author': {'email': 'mlgmxyysd@meowcat.org', 'name': 'Jim Wu'},
#      'message': 'MlgmXyysd Github Update Bot: 1575024908',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ElderDrivers/Repository-Website/commits/481f60f8cf87116c290409d2deb3490487bb4d8e'}]},
#   'public': True,
#   'created_at': '2019-11-29T10:55:11Z',
#   'org': {'id': 47079235,
#    'login': 'ElderDrivers',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ElderDrivers',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47079235?'}},
#  {'id': '10975218426',
#   'type': 'PushEvent',
#   'actor': {'id': 8761435,
#    'login': 'tnagler',
#    'display_login': 'tnagler',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tnagler',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8761435?'},
#   'repo': {'id': 86737770,
#    'name': 'vinecopulib/rvinecopulib',
#    'url': 'https://api.github.com/repos/vinecopulib/rvinecopulib'},
#   'payload': {'push_id': 4335435110,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/actions',
#    'head': 'cf41a93ccb838a3a89c5c7ac546c27109fa3cb67',
#    'before': '7ccaaad2f22fceeb6158623410e365e15b415232',
#    'commits': [{'sha': 'cf41a93ccb838a3a89c5c7ac546c27109fa3cb67',
#      'author': {'email': 'thomas.nagler@tum.de', 'name': 'tnagler'},
#      'message': 'no idea',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/vinecopulib/rvinecopulib/commits/cf41a93ccb838a3a89c5c7ac546c27109fa3cb67'}]},
#   'public': True,
#   'created_at': '2019-11-29T10:55:11Z',
#   'org': {'id': 26723846,
#    'login': 'vinecopulib',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/vinecopulib',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26723846?'}},
#  {'id': '10975218411',
#   'type': 'PushEvent',
#   'actor': {'id': 22497322,
#    'login': 'IgoSzaFIIT',
#    'display_login': 'IgoSzaFIIT',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/IgoSzaFIIT',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22497322?'},
#   'repo': {'id': 224249738,
#    'name': 'Ejdrijen/MSUS',
#    'url': 'https://api.github.com/repos/Ejdrijen/MSUS'},
#   'payload': {'push_id': 4335435108,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '3a789d0c4f6d4fa3e0e602946ad8fee6018a3149',
#    'before': '903e8a1579d3260a3d784f4dcec59ce2e70a497b',
#    'commits': [{'sha': '3a789d0c4f6d4fa3e0e602946ad8fee6018a3149',
#      'author': {'email': '31308334+Specter1337@users.noreply.github.com',
#       'name': 'Specter1337'},
#      'message': 'pridane role do faktury, typo fix',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Ejdrijen/MSUS/commits/3a789d0c4f6d4fa3e0e602946ad8fee6018a3149'}]},
#   'public': True,
#   'created_at': '2019-11-29T10:55:11Z'},
#  {'id': '10975218415',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 6681528,
#    'login': 'arteck',
#    'display_login': 'arteck',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/arteck',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6681528?'},
#   'repo': {'id': 219930762,
#    'name': 'arteck/zigbee-herdsman-converters',
#    'url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters'},
#   'payload': {'action': 'opened',
#    'number': 2,
#    'pull_request': {'url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/pulls/2',
#     'id': 346996296,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ2OTk2Mjk2',
#     'html_url': 'https://github.com/arteck/zigbee-herdsman-converters/pull/2',
#     'diff_url': 'https://github.com/arteck/zigbee-herdsman-converters/pull/2.diff',
#     'patch_url': 'https://github.com/arteck/zigbee-herdsman-converters/pull/2.patch',
#     'issue_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/issues/2',
#     'number': 2,
#     'state': 'open',
#     'locked': False,
#     'title': 'upd',
#     'user': {'login': 'arteck',
#      'id': 6681528,
#      'node_id': 'MDQ6VXNlcjY2ODE1Mjg=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/6681528?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/arteck',
#      'html_url': 'https://github.com/arteck',
#      'followers_url': 'https://api.github.com/users/arteck/followers',
#      'following_url': 'https://api.github.com/users/arteck/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/arteck/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/arteck/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/arteck/subscriptions',
#      'organizations_url': 'https://api.github.com/users/arteck/orgs',
#      'repos_url': 'https://api.github.com/users/arteck/repos',
#      'events_url': 'https://api.github.com/users/arteck/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/arteck/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'created_at': '2019-11-29T10:55:10Z',
#     'updated_at': '2019-11-29T10:55:10Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/pulls/2/commits',
#     'review_comments_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/pulls/2/comments',
#     'review_comment_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/issues/2/comments',
#     'statuses_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/statuses/22ffa0f5ab2c83f18d114f4647f5ed9a98a56611',
#     'head': {'label': 'Koenkk:master',
#      'ref': 'master',
#      'sha': '22ffa0f5ab2c83f18d114f4647f5ed9a98a56611',
#      'user': {'login': 'Koenkk',
#       'id': 2892853,
#       'node_id': 'MDQ6VXNlcjI4OTI4NTM=',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/2892853?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Koenkk',
#       'html_url': 'https://github.com/Koenkk',
#       'followers_url': 'https://api.github.com/users/Koenkk/followers',
#       'following_url': 'https://api.github.com/users/Koenkk/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Koenkk/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Koenkk/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Koenkk/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Koenkk/orgs',
#       'repos_url': 'https://api.github.com/users/Koenkk/repos',
#       'events_url': 'https://api.github.com/users/Koenkk/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Koenkk/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 134597023,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMzQ1OTcwMjM=',
#       'name': 'zigbee-herdsman-converters',
#       'full_name': 'Koenkk/zigbee-herdsman-converters',
#       'private': False,
#       'owner': {'login': 'Koenkk',
#        'id': 2892853,
#        'node_id': 'MDQ6VXNlcjI4OTI4NTM=',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/2892853?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Koenkk',
#        'html_url': 'https://github.com/Koenkk',
#        'followers_url': 'https://api.github.com/users/Koenkk/followers',
#        'following_url': 'https://api.github.com/users/Koenkk/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Koenkk/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Koenkk/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Koenkk/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Koenkk/orgs',
#        'repos_url': 'https://api.github.com/users/Koenkk/repos',
#        'events_url': 'https://api.github.com/users/Koenkk/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Koenkk/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/Koenkk/zigbee-herdsman-converters',
#       'description': 'Collection of device converters to be used with zigbee-herdsman',
#       'fork': False,
#       'url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters',
#       'forks_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/forks',
#       'keys_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/teams',
#       'hooks_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/events',
#       'assignees_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/tags',
#       'blobs_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/languages',
#       'stargazers_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/subscription',
#       'commits_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/merges',
#       'archive_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/downloads',
#       'issues_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Koenkk/zigbee-herdsman-converters/deployments',
#       'created_at': '2018-05-23T16:25:00Z',
#       'updated_at': '2019-11-28T19:25:13Z',
#       'pushed_at': '2019-11-29T07:37:56Z',
#       'git_url': 'git://github.com/Koenkk/zigbee-herdsman-converters.git',
#       'ssh_url': 'git@github.com:Koenkk/zigbee-herdsman-converters.git',
#       'clone_url': 'https://github.com/Koenkk/zigbee-herdsman-converters.git',
#       'svn_url': 'https://github.com/Koenkk/zigbee-herdsman-converters',
#       'homepage': '',
#       'size': 2412,
#       'stargazers_count': 159,
#       'watchers_count': 159,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 366,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 24,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 366,
#       'open_issues': 24,
#       'watchers': 159,
#       'default_branch': 'master'}},
#     'base': {'label': 'arteck:master',
#      'ref': 'master',
#      'sha': '51166ef5508690eed41b0a9a137203ff9912f83f',
#      'user': {'login': 'arteck',
#       'id': 6681528,
#       'node_id': 'MDQ6VXNlcjY2ODE1Mjg=',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/6681528?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/arteck',
#       'html_url': 'https://github.com/arteck',
#       'followers_url': 'https://api.github.com/users/arteck/followers',
#       'following_url': 'https://api.github.com/users/arteck/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/arteck/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/arteck/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/arteck/subscriptions',
#       'organizations_url': 'https://api.github.com/users/arteck/orgs',
#       'repos_url': 'https://api.github.com/users/arteck/repos',
#       'events_url': 'https://api.github.com/users/arteck/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/arteck/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 219930762,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMTk5MzA3NjI=',
#       'name': 'zigbee-herdsman-converters',
#       'full_name': 'arteck/zigbee-herdsman-converters',
#       'private': False,
#       'owner': {'login': 'arteck',
#        'id': 6681528,
#        'node_id': 'MDQ6VXNlcjY2ODE1Mjg=',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/6681528?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/arteck',
#        'html_url': 'https://github.com/arteck',
#        'followers_url': 'https://api.github.com/users/arteck/followers',
#        'following_url': 'https://api.github.com/users/arteck/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/arteck/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/arteck/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/arteck/subscriptions',
#        'organizations_url': 'https://api.github.com/users/arteck/orgs',
#        'repos_url': 'https://api.github.com/users/arteck/repos',
#        'events_url': 'https://api.github.com/users/arteck/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/arteck/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/arteck/zigbee-herdsman-converters',
#       'description': 'Collection of device converters to be used with zigbee-herdsman',
#       'fork': True,
#       'url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters',
#       'forks_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/forks',
#       'keys_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/teams',
#       'hooks_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/hooks',
#       'issue_events_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/events',
#       'assignees_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/tags',
#       'blobs_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/languages',
#       'stargazers_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/stargazers',
#       'contributors_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/contributors',
#       'subscribers_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/subscribers',
#       'subscription_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/subscription',
#       'commits_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/merges',
#       'archive_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/downloads',
#       'issues_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/deployments',
#       'created_at': '2019-11-06T06:50:36Z',
#       'updated_at': '2019-11-20T06:31:45Z',
#       'pushed_at': '2019-11-20T06:31:44Z',
#       'git_url': 'git://github.com/arteck/zigbee-herdsman-converters.git',
#       'ssh_url': 'git@github.com:arteck/zigbee-herdsman-converters.git',
#       'clone_url': 'https://github.com/arteck/zigbee-herdsman-converters.git',
#       'svn_url': 'https://github.com/arteck/zigbee-herdsman-converters',
#       'homepage': '',
#       'size': 2424,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/pulls/2'},
#      'html': {'href': 'https://github.com/arteck/zigbee-herdsman-converters/pull/2'},
#      'issue': {'href': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/issues/2'},
#      'comments': {'href': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/issues/2/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/pulls/2/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/pulls/2/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/arteck/zigbee-herdsman-converters/statuses/22ffa0f5ab2c83f18d114f4647f5ed9a98a56611'}},
#     'author_association': 'OWNER',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 22,
#     'additions': 95,
#     'deletions': 45,
#     'changed_files': 4}},
#   'public': True,
#   'created_at': '2019-11-29T10:55:11Z'},
#  {'id': '10975218414',
#   'type': 'CreateEvent',
#   'actor': {'id': 55400815,
#    'login': 'lam1051999',
#    'display_login': 'lam1051999',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lam1051999',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55400815?'},
#   'repo': {'id': 224836130,
#    'name': 'lam1051999/BTLDssv',
#    'url': 'https://api.github.com/repos/lam1051999/BTLDssv'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-11-29T10:55:11Z'},
#  {'id': '10975218405',
#   'type': 'CreateEvent',
#   'actor': {'id': 1565469,
#    'login': 'exo-swf',
#    'display_login': 'exo-swf',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/exo-swf',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1565469?'},
#   'repo': {'id': 4126221,
#    'name': 'exoplatform/wiki',
#    'url': 'https://api.github.com/repos/exoplatform/wiki'},
#   'payload': {'ref': '6.0.0-M09',
#    'ref_type': 'tag',
#    'master_branch': 'develop',
#    'description': 'eXo Wiki',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-11-29T10:55:11Z',
#   'org': {'id': 259384,
#    'login': 'exoplatform',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/exoplatform',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/259384?'}},
#  {'id': '10975218398',
#   'type': 'WatchEvent',
#   'actor': {'id': 10251763,
#    'login': 'dbaspider',
#    'display_login': 'dbaspider',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dbaspider',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10251763?'},
#   'repo': {'id': 38415799,
#    'name': 'WuXiaolong/PullLoadMoreRecyclerView',
#    'url': 'https://api.github.com/repos/WuXiaolong/PullLoadMoreRecyclerView'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-11-29T10:55:11Z'},
#  {'id': '10975218404',
#   'type': 'CreateEvent',
#   'actor': {'id': 1565469,
#    'login': 'exo-swf',
#    'display_login': 'exo-swf',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/exo-swf',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1565469?'},
#   'repo': {'id': 4438600,
#    'name': 'exoplatform/calendar',
#    'url': 'https://api.github.com/repos/exoplatform/calendar'},
#   'payload': {'ref': '5.3.0-RC09',
#    'ref_type': 'tag',
#    'master_branch': 'develop',
#    'description': 'eXo Calendar',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-11-29T10:55:11Z',
#   'org': {'id': 259384,
#    'login': 'exoplatform',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/exoplatform',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/259384?'}},
#  {'id': '10975218389',
#   'type': 'PushEvent',
#   'actor': {'id': 13799883,
#    'login': 'AJTPTW',
#    'display_login': 'AJTPTW',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AJTPTW',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13799883?'},
#   'repo': {'id': 86557434,
#    'name': 'AJTPTW/zoznn',
#    'url': 'https://api.github.com/repos/AJTPTW/zoznn'},
#   'payload': {'push_id': 4335435093,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd9a1073f49900aaaa3bb427764d453afcfb6626e',
#    'before': 'cc58d891b12c372d9b47efa81fdcded9c570b8ea',
#    'commits': [{'sha': 'd9a1073f49900aaaa3bb427764d453afcfb6626e',
#      'author': {'email': 'zhiweiwin@gmail.com', 'name': 'zooo'},
#      'message': 'Delete tampermonkey-backup-chrome-2019-11-28T11-37-04.913Z.zip',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/AJTPTW/zoznn/commits/d9a1073f49900aaaa3bb427764d453afcfb6626e'}]},
#   'public': True,
#   'created_at': '2019-11-29T10:55:11Z'},
#  {'id': '10975218379',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 102737539,
#    'name': 'Lombiq/Hastlayer-SDK',
#    'url': 'https://api.github.com/repos/Lombiq/Hastlayer-SDK'},
#   'payload': {'push_id': 4335435087,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/issue/HAST-133',
#    'head': 'b21403ab32de6d379e128a28035e39d0fed68141',
#    'before': 'b21403ab32de6d379e128a28035e39d0fed68141',
#    'commits': []},
#   'public': True,
#   'created_at': '2019-11-29T10:55:10Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '10975218372',
#   'type': 'PushEvent',
#   'actor': {'id': 58036601,
#    'login': 'MacTrissy',
#    'display_login': 'MacTrissy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MacTrissy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58036601?'},
#   'repo': {'id': 216111368,
#    'name': 'Gamertoc/University-EPR',
#    'url': 'https://api.github.com/repos/Gamertoc/University-EPR'},
#   'payload': {'push_id': 4335435084,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'b8bec2151fae5ccd8d5d1ab83fd0e6d95faccdb2',
#    'before': '157b8d4a8dd9720defbe4c79b83505811d2778da',
#    'commits': [{'sha': 'b8bec2151fae5ccd8d5d1ab83fd0e6d95faccdb2',
#      'author': {'email': '58036601+MacTrissy@users.noreply.github.com',
#       'name': 'MacTrissy'},
#      'message': 'Delete in.arbeit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Gamertoc/University-EPR/commits/b8bec2151fae5ccd8d5d1ab83fd0e6d95faccdb2'}]},
#   'public': True,
#   'created_at': '2019-11-29T10:55:10Z'},
#  {'id': '10975218359',
#   'type': 'WatchEvent',
#   'actor': {'id': 2505002,
#    'login': 'a08381',
#    'display_login': 'a08381',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/a08381',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2505002?'},
#   'repo': {'id': 47009706,
#    'name': 'FFXIVAPP/sharlayan',
#    'url': 'https://api.github.com/repos/FFXIVAPP/sharlayan'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-11-29T10:55:10Z',
#   'org': {'id': 15843634,
#    'login': 'FFXIVAPP',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/FFXIVAPP',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15843634?'}},
#  {'id': '10975218354',
#   'type': 'WatchEvent',
#   'actor': {'id': 101044,
#    'login': 'clowder',
#    'display_login': 'clowder',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/clowder',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101044?'},
#   'repo': {'id': 1147007,
#    'name': 'garybernhardt/dotfiles',
#    'url': 'https://api.github.com/repos/garybernhardt/dotfiles'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-11-29T10:55:10Z'},
#  {'id': '10975218334',
#   'type': 'WatchEvent',
#   'actor': {'id': 832185,
#    'login': 'kdubovikov',
#    'display_login': 'kdubovikov',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kdubovikov',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/832185?'},
#   'repo': {'id': 144636984,
#    'name': 'parrt/dtreeviz',
#    'url': 'https://api.github.com/repos/parrt/dtreeviz'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-11-29T10:55:10Z'},
#  {'id': '10975218307',
#   'type': 'PushEvent',
#   'actor': {'id': 566926,
#    'login': 'tiagobalmeida',
#    'display_login': 'tiagobalmeida',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tiagobalmeida',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/566926?'},
#   'repo': {'id': 110880512,
#    'name': 'tiagobalmeida/openui5-camera',
#    'url': 'https://api.github.com/repos/tiagobalmeida/openui5-camera'},
#   'payload': {'push_id': 4335435055,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ee68b5037dbe46e25246c8ed3c2f8f554927d332',
#    'before': 'c4ef9f61da61ef0cae5a0a334ef0875433963734',
#    'commits': [{'sha': 'ee68b5037dbe46e25246c8ed3c2f8f554927d332',
#      'author': {'email': 'jumpifzero@gmail.com', 'name': 'Tiago Almeida'},
#      'message': 'Fixes broken demo URL after github nickname change',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tiagobalmeida/openui5-camera/commits/ee68b5037dbe46e25246c8ed3c2f8f554927d332'}]},
#   'public': True,
#   'created_at': '2019-11-29T10:55:10Z'},
#  {'id': '10975218315',
#   'type': 'PushEvent',
#   'actor': {'id': 5078921,
#    'login': 'Nishchit14',
#    'display_login': 'Nishchit14',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Nishchit14',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5078921?'},
#   'repo': {'id': 224816310,
#    'name': 'Nishchit14/express-ably-channels',
#    'url': 'https://api.github.com/repos/Nishchit14/express-ably-channels'},
#   'payload': {'push_id': 4335435058,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'dacbfa7a88910343667b79a2fb14621b6a50133e',
#    'before': '36656e0444ef07f2ad142839f6443bfaadef884e',
#    'commits': [{'sha': 'dacbfa7a88910343667b79a2fb14621b6a50133e',
#      'author': {'email': 'dnishchit@gmail.com', 'name': 'Nishchit Dhanani'},
#      'message': 'doc added',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Nishchit14/express-ably-channels/commits/dacbfa7a88910343667b79a2fb14621b6a50133e'}]},
#   'public': True,
#   'created_at': '2019-11-29T10:55:10Z'},
#  {'id': '10975218314',
#   'type': 'WatchEvent',
#   'actor': {'id': 24992586,
#    'login': 'nvthuong1996',
#    'display_login': 'nvthuong1996',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nvthuong1996',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24992586?'},
#   'repo': {'id': 172197546,
#    'name': 'vaygeth89/reactive_flutter_todo_database_app',
#    'url': 'https://api.github.com/repos/vaygeth89/reactive_flutter_todo_database_app'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-11-29T10:55:10Z'},
#  {'id': '10975218311',
#   'type': 'DeleteEvent',
#   'actor': {'id': 42873674,
#    'login': 'CircleJanewayTest',
#    'display_login': 'CircleJanewayTest',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CircleJanewayTest',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42873674?'},
#   'repo': {'id': 164702370,
#    'name': 'CircleCITestOrg/smoke-test-test-repo',
#    'url': 'https://api.github.com/repos/CircleCITestOrg/smoke-test-test-repo'},
#   'payload': {'ref': 'build-workspaces-2019-11-29T10-53-17',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-11-29T10:55:10Z',
#   'org': {'id': 32499712,
#    'login': 'CircleCITestOrg',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/CircleCITestOrg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32499712?'}},
#  {'id': '10975218305',
#   'type': 'PushEvent',
#   'actor': {'id': 12983386,
#    'login': 'athorsen',
#    'display_login': 'athorsen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/athorsen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12983386?'},
#   'repo': {'id': 224835508,
#    'name': 'athorsen/rust-messaging',
#    'url': 'https://api.github.com/repos/athorsen/rust-messaging'},
#   'payload': {'push_id': 4335435059,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'fff38db26df1416cf2684417ff2e7d684418e907',
#    'before': 'a9d19a1fe5f1ccacfeadbf9df5399d645fec4439',
#    'commits': [{'sha': 'fff38db26df1416cf2684417ff2e7d684418e907',
#      'author': {'email': 'tony@tonythorsen.com', 'name': 'Tony Thorsen'},
#      'message': 'Porting over from CodeCommit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/athorsen/rust-messaging/commits/fff38db26df1416cf2684417ff2e7d684418e907'}]},
#   'public': True,
#   'created_at': '2019-11-29T10:55:10Z'},
#  {'id': '10975218300',
#   'type': 'PushEvent',
#   'actor': {'id': 58298942,
#    'login': 'Liam-Treacy98',
#    'display_login': 'Liam-Treacy98',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Liam-Treacy98',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58298942?'},
# ...
#      'creator': {'login': 'lumip',
#       'id': 4107081,
#       'node_id': 'MDQ6VXNlcjQxMDcwODE=',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/4107081?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/lumip',
#       'html_url': 'https://github.com/lumip',
#       'followers_url': 'https://api.github.com/users/lumip/followers',
#       'following_url': 'https://api.github.com/users/lumip/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/lumip/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/lumip/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/lumip/subscriptions',
#       'organizations_url': 'https://api.github.com/users/lumip/orgs',
#       'repos_url': 'https://api.github.com/users/lumip/repos',
#       'events_url': 'https://api.github.com/users/lumip/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/lumip/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'open_issues': 7,
#      'closed_issues': 10,
#      'state': 'open',
#      'created_at': '2018-06-28T09:48:54Z',
#      'updated_at': '2018-09-14T15:08:47Z',
#      'due_on': None,
#      'closed_at': None},
#     'comments': 2,
#     'created_at': '2018-08-16T07:00:18Z',
#     'updated_at': '2019-11-29T10:55:09Z',
#     'closed_at': None,
#     'author_association': 'MEMBER',
#     'body': 'After sequencing a pulse to obtain a program, it is often desirable to change some parameters without starting the entire sequencing again. Ideally this would also be supported by hardware drivers to avoid costly re-uploads of pulses (if possible) to the hardware device.\r\nTask:\r\nImplement a method `update_program(parameters)` to achieve this desired behavior. \r\n\r\nIt is currently unclear whether this should be part of the `Loop` class (which is currently not exposed to end-users) or of the `PulseTemplate` class (then taking a `Loop` instance which will be updated as an argument). It could also be conceivable to wrap the `Loop` class in a class `Program` which can expose a clean interface to the user and handle a `Loop` instance internally.\r\n\r\nAlso depends on changes to parameter management, especially the ability to mark parameters as volatile. Due to that, this issue should be tackled after #280 is completed.'},
#    'comment': {'url': 'https://api.github.com/repos/qutech/qupulse/issues/comments/559750997',
#     'html_url': 'https://github.com/qutech/qupulse/issues/342#issuecomment-559750997',
#     'issue_url': 'https://api.github.com/repos/qutech/qupulse/issues/342',
#     'id': 559750997,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU1OTc1MDk5Nw==',
#     'user': {'login': 'terrorfisch',
#      'id': 3215896,
#      'node_id': 'MDQ6VXNlcjMyMTU4OTY=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/3215896?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/terrorfisch',
#      'html_url': 'https://github.com/terrorfisch',
#      'followers_url': 'https://api.github.com/users/terrorfisch/followers',
#      'following_url': 'https://api.github.com/users/terrorfisch/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/terrorfisch/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/terrorfisch/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/terrorfisch/subscriptions',
#      'organizations_url': 'https://api.github.com/users/terrorfisch/orgs',
#      'repos_url': 'https://api.github.com/users/terrorfisch/repos',
#      'events_url': 'https://api.github.com/users/terrorfisch/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/terrorfisch/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-11-29T10:55:09Z',
#     'updated_at': '2019-11-29T10:55:09Z',
#     'author_association': 'MEMBER',
#     'body': 'The data acquisition machinery also needs support for this.'}},
#   'public': True,
#   'created_at': '2019-11-29T10:55:10Z',
#   'org': {'id': 10435688,
#    'login': 'qutech',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/qutech',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10435688?'}},
#  {'id': '10975218295',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 44970163,
#    'login': 'gamaya-developer',
#    'display_login': 'gamaya-developer',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gamaya-developer',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44970163?'},
#   'repo': {'id': 108311273,
#    'name': 'Azure/azure-sdk-for-js',
#    'url': 'https://api.github.com/repos/Azure/azure-sdk-for-js'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/Azure/azure-sdk-for-js/issues/6352',
#     'repository_url': 'https://api.github.com/repos/Azure/azure-sdk-for-js',
#     'labels_url': 'https://api.github.com/repos/Azure/azure-sdk-for-js/issues/6352/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/Azure/azure-sdk-for-js/issues/6352/comments',
#     'events_url': 'https://api.github.com/repos/Azure/azure-sdk-for-js/issues/6352/events',
#     'html_url': 'https://github.com/Azure/azure-sdk-for-js/issues/6352',
#     'id': 529611483,
#     'node_id': 'MDU6SXNzdWU1Mjk2MTE0ODM=',
#     'number': 6352,
#     'title': "option 'onProgress'  breaks stageBlock",
#     'user': {'login': 'gamaya-developer',
#      'id': 44970163,
#      'node_id': 'MDQ6VXNlcjQ0OTcwMTYz',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/44970163?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/gamaya-developer',
#      'html_url': 'https://github.com/gamaya-developer',
#      'followers_url': 'https://api.github.com/users/gamaya-developer/followers',
#      'following_url': 'https://api.github.com/users/gamaya-developer/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/gamaya-developer/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/gamaya-developer/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/gamaya-developer/subscriptions',
#      'organizations_url': 'https://api.github.com/users/gamaya-developer/orgs',
#      'repos_url': 'https://api.github.com/users/gamaya-developer/repos',
#      'events_url': 'https://api.github.com/users/gamaya-developer/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/gamaya-developer/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1178451695,
#       'node_id': 'MDU6TGFiZWwxMTc4NDUxNjk1',
#       'url': 'https://api.github.com/repos/Azure/azure-sdk-for-js/labels/Client',
#       'name': 'Client',
#       'color': 'ffeb77',
#       'default': False,
#       'description': 'Issues that refer to the client sdk'},
#      {'id': 1243381603,
#       'node_id': 'MDU6TGFiZWwxMjQzMzgxNjAz',
#       'url': 'https://api.github.com/repos/Azure/azure-sdk-for-js/labels/Storage',
#       'name': 'Storage',
#       'color': 'e99695',
#       'default': False,
#       'description': 'Storage Service (Queues, Blobs, Files)'},
#      {'id': 1118446762,
#       'node_id': 'MDU6TGFiZWwxMTE4NDQ2NzYy',
#       'url': 'https://api.github.com/repos/Azure/azure-sdk-for-js/labels/customer-reported',
#       'name': 'customer-reported',
#       'color': '3800e0',
#       'default': False,
#       'description': 'Issues that are reported by GitHub users external to the Azure organization.'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': {'login': 'XiaoningLiu',
#      'id': 6889160,
#      'node_id': 'MDQ6VXNlcjY4ODkxNjA=',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/6889160?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/XiaoningLiu',
#      'html_url': 'https://github.com/XiaoningLiu',
#      'followers_url': 'https://api.github.com/users/XiaoningLiu/followers',
#      'following_url': 'https://api.github.com/users/XiaoningLiu/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/XiaoningLiu/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/XiaoningLiu/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/XiaoningLiu/subscriptions',
#      'organizations_url': 'https://api.github.com/users/XiaoningLiu/orgs',
#      'repos_url': 'https://api.github.com/users/XiaoningLiu/repos',
#      'events_url': 'https://api.github.com/users/XiaoningLiu/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/XiaoningLiu/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'XiaoningLiu',
#       'id': 6889160,
#       'node_id': 'MDQ6VXNlcjY4ODkxNjA=',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/6889160?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/XiaoningLiu',
#       'html_url': 'https://github.com/XiaoningLiu',
#       'followers_url': 'https://api.github.com/users/XiaoningLiu/followers',
#       'following_url': 'https://api.github.com/users/XiaoningLiu/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/XiaoningLiu/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/XiaoningLiu/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/XiaoningLiu/subscriptions',
#       'organizations_url': 'https://api.github.com/users/XiaoningLiu/orgs',
#       'repos_url': 'https://api.github.com/users/XiaoningLiu/repos',
#       'events_url': 'https://api.github.com/users/XiaoningLiu/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/XiaoningLiu/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'ljian3377',
#       'id': 8168282,
#       'node_id': 'MDQ6VXNlcjgxNjgyODI=',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/8168282?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ljian3377',
#       'html_url': 'https://github.com/ljian3377',
#       'followers_url': 'https://api.github.com/users/ljian3377/followers',
#       'following_url': 'https://api.github.com/users/ljian3377/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ljian3377/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ljian3377/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ljian3377/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ljian3377/orgs',
#       'repos_url': 'https://api.github.com/users/ljian3377/repos',
#       'events_url': 'https://api.github.com/users/ljian3377/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ljian3377/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2019-11-27T23:10:19Z',
#     'updated_at': '2019-11-29T10:55:09Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': "- **Package Name**: @azure/storage-blob\r\n- **Package Version**: 12.0.0\r\n- **Operating system**:  macOS Catalina\r\n- **Electron**: 7.1.2 \r\n- [ ] **nodejs** \r\n    - **version**: 12.8.1\r\n- [ ] **browser**\r\n    - **name/version**:  electron\r\n- [ ] **typescript**\r\n    - **version**: 3.5.3\r\n- Is the bug related to **documentation** in\r\n  - [ ] README.md\r\n  - [ ] source code documentation\r\n  - [ ] SDK API docs on https://docs.microsoft.com\r\n\r\n**Describe the bug**\r\nElectron app which uploads images by blocks and commit these blocks to blob file.\r\nFlow is: stageBlock -> commitBlockList\r\nIf I put option 'onProgress' to stageBlock, blocks will uploaded incorrectly.\r\n`blockBlobClient.stageBlock(blockId, body, contentLength, {\r\n      onProgress: (data) => console.log(data)\r\n    })`\r\nAlthough without 'onProgress' everything is fine.\r\n`blockBlobClient.stageBlock(blockId, body, contentLength)`\r\n\r\n**To Reproduce**\r\nSteps to reproduce the behavior:\r\n1. split big image by blocks using `fs.createReadStream`\r\n2. upload each block using `stageBlock` method\r\n3. join blocks together using commitBlockList \r\n\r\n**Expected behavior**\r\nafter adding 'onProgress' callback the blocks should upload the same as without it.\r\n\r\n**Screenshots**\r\nIf applicable, add screenshots to help explain your problem.\r\n\r\n**Additional context**\r\nNoticed that 'loadedBytes' which is available in 'onProgress' callback in the last call is not the same as total size of block.\r\n'body' is readable stream created by `fs.createReadStream`\r\nNo errors and other warnings.\r\n"},
#    'comment': {'url': 'https://api.github.com/repos/Azure/azure-sdk-for-js/issues/comments/559750996',
#     'html_url': 'https://github.com/Azure/azure-sdk-for-js/issues/6352#issuecomment-559750996',
#     'issue_url': 'https://api.github.com/repos/Azure/azure-sdk-for-js/issues/6352',
#     'id': 559750996,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU1OTc1MDk5Ng==',
#     'user': {'login': 'gamaya-developer',
#      'id': 44970163,
#      'node_id': 'MDQ6VXNlcjQ0OTcwMTYz',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/44970163?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/gamaya-developer',
#      'html_url': 'https://github.com/gamaya-developer',
#      'followers_url': 'https://api.github.com/users/gamaya-developer/followers',
#      'following_url': 'https://api.github.com/users/gamaya-developer/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/gamaya-developer/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/gamaya-developer/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/gamaya-developer/subscriptions',
#      'organizations_url': 'https://api.github.com/users/gamaya-developer/orgs',
#      'repos_url': 'https://api.github.com/users/gamaya-developer/repos',
#      'events_url': 'https://api.github.com/users/gamaya-developer/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/gamaya-developer/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-11-29T10:55:09Z',
#     'updated_at': '2019-11-29T10:55:09Z',
#     'author_association': 'NONE',
#     'body': 'Hi! The final blob file, in my case the image. When you open it is easy to understand that is broken. During uploading no errors\r\n![banter-snaps-ChFD5fj6Rqc-unsplash 2](https://user-images.githubusercontent.com/44970163/69864352-6580ce00-12a7-11ea-9275-cf360eaad910.jpg)\r\n![broken_banter-snaps-ChFD5fj6Rqc-unsplash](https://user-images.githubusercontent.com/44970163/69864353-6580ce00-12a7-11ea-80f3-234270fb6552.jpg)\r\n\r\n'}},
#   'public': True,
#   'created_at': '2019-11-29T10:55:10Z',
#   'org': {'id': 6844498,
#    'login': 'Azure',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Azure',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6844498?'}},
#  {'id': '10975218294',
#   'type': 'PushEvent',
#   'actor': {'id': 1952799,
#    'login': 'gianlucatruda',
#    'display_login': 'gianlucatruda',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gianlucatruda',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1952799?'},
#   'repo': {'id': 221669970,
#    'name': 'gianlucatruda/sir2019-study-buddy-group-7',
#    'url': 'https://api.github.com/repos/gianlucatruda/sir2019-study-buddy-group-7'},
#   'payload': {'push_id': 4335435051,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dev',
#    'head': 'e5edfd80b42244099badc36853f609661e04d0dc',
#    'before': 'c878e88e0253193e431a9681d92f4dbddb8df9c8',
#    'commits': [{'sha': 'e5edfd80b42244099badc36853f609661e04d0dc',
#      'author': {'email': 'gianlucatruda@gmail.com', 'name': 'Gianluca Truda'},
#      'message': 'Added gestures and eye colour to complement state and empathy.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/gianlucatruda/sir2019-study-buddy-group-7/commits/e5edfd80b42244099badc36853f609661e04d0dc'}]},
#   'public': True,
#   'created_at': '2019-11-29T10:55:10Z'}]

# %% [markdown]
# ## 其它用法

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get")
#json.loads(r.text)
r2 = requests.get("http://httpbin.org/get", params=payload)
json.loads(r2.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0'},
#  'origin': '220.137.92.121, 220.137.92.121',
#  'url': 'https://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.19.1'},
#  'json': None,
#  'origin': '123.195.194.127, 123.195.194.127',
#  'url': 'https://httpbin.org/post'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0'},
#  'json': None,
#  'origin': '220.137.92.121, 220.137.92.121',
#  'url': 'https://httpbin.org/post'}

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)
